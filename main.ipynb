# %%
import pandas as pd
import json
import os

# %%
df = pd.read_csv('dataset_2018_01.csv')

# %%
df.head()
# Out:
#                                                title   published  \
# 0  Emerging markets are set for an even bigger ra...  2018-01-03
# 1  Cramer reflects on how Trump's actions are fue...  2018-01-03
# 2  The Wall Street Journal: Peter Thiel’s VC firm...  2018-01-03
# 3  Hoda Kotb Will Replace Matt Lauer on NBC’s ‘To...  2018-01-02
# 4  UK's Compass says new CEO to start Jan 1 after...  2018-01-01
#
#                                                 text
# 0  17 Hours Ago | 02:56 Emerging markets soared m...
# 1  Cramer reflects on how Trump's actions are fue...
# 2  Published: Jan 2, 2018 5:59 p.m. ET Share Few ...
# 3  By Reuters 8:23 AM EST Television host Hoda Ko...
# 4  January 1, 2018 / 8:56 AM / Updated 5 hours ag...

# %%
df.shape
# Out:
# (57802, 3)

# %% [markdown]
# ### Remove articles that are too short ot too long (<100, >100000)

# %%
df = df[(df['text'].str.len() >= 100) & (df['text'].str.len() <= 100000)]

# %%
df.shape
# Out:
# (56885, 3)

# %% [markdown]
# ### NER model

# %%
# Preproccessing data

# %%
df['text'] = df['text'].astype(str)
# because of the TypeError: 'float' object is not iterable

# %%
non_ascii_values = df['text'].apply(lambda x: any(ord(char) > 128 for char in x))
print(non_ascii_values)
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 57797     True
# 57798     True
# 57799     True
# 57800     True
# 57801     True
# Name: text, Length: 57802, dtype: bool

# %%
def remove_non_ascii(text):
    return ''.join(char for char in text if ord(char) < 128)

df['text'] = df['text'].apply(remove_non_ascii)

# %%
non_ascii_values = df['text'].apply(lambda x: any(ord(char) > 128 for char in x))
print(non_ascii_values)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 57797    False
# 57798    False
# 57799    False
# 57800    False
# 57801    False
# Name: text, Length: 57802, dtype: bool

# %%
# pre-trained English model for Named Entity Recognition (NER)

# %%
import spacy
model_ner = spacy.load("en_core_web_sm")

# %%
def extract_org(text):
    doc = model_ner(text)
    orgs = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
    return ', '.join(orgs) if orgs else None

# %%
df['org_names'] = df['title'].apply(extract_org)

# %%
df = df.dropna(subset=['org_names'])

# %%
excluded_names = {"bloomberg", "reuters", "cnbc", "nbc", "the wall street journal", "wsj", "fortune", "nbc news today", "trump"}

# %%
df = df[~df['org_names'].str.lower().str.contains('|'.join(excluded_names))] # ~ operator negates the condition

# %%
df = df[df['org_names'].str.count(',') == 0]

# %%
df.head()
# Out:
#                                                 title   published  \
# 9   Intel's alleged security flaw could cost chipm...  2018-01-03
# 21  Tesla delivers 1,550 Model 3 sedans and 29,870...  2018-01-03
# 26  US looks good in 2018, but stocks abroad look ...  2018-01-02
# 28           China's WeChat denies storing user chats  2018-01-02
# 43  Weight Watchers rallies after DJ Khaled signin...  2018-01-02
#
#                                                  text        org_names
# 9   A report alleging Intel chips have a security ...            Intel
# 21  Tesla is apparently still deep in the circles ...            Tesla
# 26  US looks good in 2018, but stocks abroad look ...          Invesco
# 28  January 2, 2018 / 7:00 AM / Updated 11 hours a...           WeChat
# 43  Shares of Weight Watchers rose nearly 6 percen...  Weight Watchers

# %%
df.shape
# Out:
# (23537, 4)

# %%
# unique_org_names_df = df['org_names'].drop_duplicates().reset_index(drop=True)
# unique_org_names_df = pd.DataFrame(unique_org_names_df, columns=['org_names'])

# %%
#df.to_csv('df_after_ner.csv', index=False)

# %% [markdown]
# ### Adding tickers. Fuzzy matching at scale

# %%
# US company tickers taken from https://www.sec.gov/file/company-tickers
company_ticker = pd.read_json('company_tickers.json', orient='index')
company_ticker = company_ticker[['ticker', 'title']]
company_ticker.head()
# Out:
#   ticker           title
# 0   MSFT  MICROSOFT CORP
# 1   AAPL      Apple Inc.
# 2   NVDA     NVIDIA CORP
# 3   AMZN  AMAZON COM INC
# 4  GOOGL   Alphabet Inc.

# %%
df = pd.read_csv('df_after_ner.csv')

# %%
import re
from ftfy import fix_text
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

# %%
# cleaning and splitting into ngrams
def ngrams(string, n=3):
    string = str(string)
    string = fix_text(string) # remove encoding mix-ups
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower()
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string)
    string = string.replace('&', 'and')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    string = string.title() # capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
org_name_clean = company_ticker['title'].unique()

# %%
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams, lowercase=False)
tfidf = vectorizer.fit_transform(org_name_clean)
print('Vecorizing completed')
# Out:
# Vecorizing completed...

# %%
nbrs = NearestNeighbors(n_neighbors=1, n_jobs=-1).fit(tfidf)

# %%
org_column = 'org_names' #column to match against in the messy data
unique_org = set(df[org_column].values) # set used for increased performance

# %%
# matching query:
def getNearestN(query):
    queryTFIDF_ = vectorizer.transform(query)
    distances, indices = nbrs.kneighbors(queryTFIDF_)
    return distances, indices

# %%
import time
t1 = time.time()
print('getting nearest n...')
distances, indices = getNearestN(unique_org)
t = time.time()-t1
print("COMPLETED IN:", t)
# Out:
# getting nearest n...
# COMPLETED IN: 3.6471893787384033

# %%
unique_org = list(unique_org) # need to convert back to a list
print('finding matches...')
matches = []
for i,j in enumerate(indices):
    temp = [round(distances[i][0],2), company_ticker.values[j][0][1],unique_org[i]]
    matches.append(temp)
    
print('Building data frame...')  
matches = pd.DataFrame(matches, columns=['match_confidence_lower_is_better','matched_name','origional_name'])
print('Done')
# Out:
# finding matches...
# Building data frame...
# Done

# %%
matches.head()
# Out:
#    match_confidence_lower_is_better                 matched_name  \
# 0                              1.16                 ING GROEP NV
# 1                              0.34  NEXTERA ENERGY PARTNERS, LP
# 2                              1.17       Greenpro Capital Corp.
# 3                              0.79            HSBC HOLDINGS PLC
# 4                              1.00               Lenzing AG/ADR
#
#                         origional_name
# 0  WealthEngine Creates Advisory Board
# 1              NextEra Energy Partners
# 2                       BRIEF-Stenprop
# 3   Southern California Super Lawyers'
# 4      Aerie Pharmaceuticals Announces

# %%
matches_filtered = matches[matches['match_confidence_lower_is_better'] < 0.78]
matches_filtered
# Out:
#        match_confidence_lower_is_better                   matched_name  \
# 1                                  0.34    NEXTERA ENERGY PARTNERS, LP
# 15                                 0.75          HUGOTON ROYALTY TRUST
# 21                                 0.15       Borqs Technologies, Inc.
# 29                                 0.72          INDEPENDENT BANK CORP
# 39                                 0.77                      WIPRO LTD
# ...                                 ...                            ...
# 13638                              0.00                  Airbus SE/ADR
# 13663                              0.73        CRA INTERNATIONAL, INC.
# 13669                              0.26            PROCTER & GAMBLE Co
# 13690                              0.60   TSAKOS ENERGY NAVIGATION LTD
# 13693                              0.61  Adverum Biotechnologies, Inc.
#
#                              origional_name
# 1                   NextEra Energy Partners
# 15     BRIEF-Hugoton Royalty Trust Declares
# 21                       Borqs Technologies
# 29     Independent Bank Corporation Reports
# 39                            Wipro Limited
# ...                                     ...
# 13638                           GasLog Ltd.
# 13663                     WTA International
# 13669                    Procter and Gamble
# 13690    Tsakos Energy Navigation Announces
# 13693         BRIEF-Adverum Biotechnologies
#
# [1588 rows x 3 columns]

# %%
matches_filtered = matches_filtered.merge(company_ticker, left_on='matched_name', right_on='title', how='left').drop(columns=['title'])

# %%
matches_filtered.shape
# Out:
# (2478, 4)

# %%
matches_filtered.tail()
# Out:
#       match_confidence_lower_is_better                   matched_name  \
# 2473                              0.26            PROCTER & GAMBLE Co
# 2474                              0.60   TSAKOS ENERGY NAVIGATION LTD
# 2475                              0.60   TSAKOS ENERGY NAVIGATION LTD
# 2476                              0.60   TSAKOS ENERGY NAVIGATION LTD
# 2477                              0.61  Adverum Biotechnologies, Inc.
#
#                           origional_name  ticker
# 2473                  Procter and Gamble      PG
# 2474  Tsakos Energy Navigation Announces     TNP
# 2475  Tsakos Energy Navigation Announces  TNP-PE
# 2476  Tsakos Energy Navigation Announces  TNP-PF
# 2477       BRIEF-Adverum Biotechnologies    ADVM

# %%
matches_filtered2 = matches_filtered.drop_duplicates(subset='matched_name', keep='first')

# %%
matches_filtered2.tail()
# Out:
#       match_confidence_lower_is_better                        matched_name  \
# 2458                              0.74  PNC FINANCIAL SERVICES GROUP, INC.
# 2468                              0.32        Delek Logistics Partners, LP
# 2469                              0.00                     ALAMO GROUP INC
# 2474                              0.60        TSAKOS ENERGY NAVIGATION LTD
# 2477                              0.61       Adverum Biotechnologies, Inc.
#
#                           origional_name ticker
# 2458                       PNC Financial    PNC
# 2468            Delek Logistics Partners    DKL
# 2469                    Alamo Group Inc.    ALG
# 2474  Tsakos Energy Navigation Announces    TNP
# 2477       BRIEF-Adverum Biotechnologies   ADVM

# %%
matches_filtered2.shape
# Out:
# (1158, 4)

# %%
master = df.copy()

# %%
master.head()
# Out:
#                                                title   published  \
# 0  Intel's alleged security flaw could cost chipm...  2018-01-03
# 1  Tesla delivers 1,550 Model 3 sedans and 29,870...  2018-01-03
# 2  US looks good in 2018, but stocks abroad look ...  2018-01-02
# 3           China's WeChat denies storing user chats  2018-01-02
# 4  Weight Watchers rallies after DJ Khaled signin...  2018-01-02
#
#                                                 text        org_names
# 0  A report alleging Intel chips have a security ...            Intel
# 1  Tesla is apparently still deep in the circles ...            Tesla
# 2  US looks good in 2018, but stocks abroad look ...          Invesco
# 3  January 2, 2018 / 7:00 AM / Updated 11 hours a...           WeChat
# 4  Shares of Weight Watchers rose nearly 6 percen...  Weight Watchers

# %%
master = pd.merge(master, matches_filtered2, left_on='org_names', right_on='origional_name', how='inner')
master.dropna(subset=['origional_name'], inplace=True)

# %%
master = master.drop(columns=['origional_name', 'match_confidence_lower_is_better'])

# %%
master.head()
# Out:
#                                                title   published  \
# 0  Intel's alleged security flaw could cost chipm...  2018-01-03
# 1  Intel CEO: We believe we have the right fixes ...  2018-01-03
# 2  Intel just warned that its patches can cause p...  2018-01-12
# 3  Intel could breakout on earnings, here’s how t...  2018-01-24
# 4        Intel set to report earnings after the bell  2018-01-25
#
#                                                 text org_names matched_name  \
# 0  A report alleging Intel chips have a security ...     Intel   INTEL CORP
# 1  Intel CEO Brian Krzanich said researchers at G...     Intel   INTEL CORP
# 2  Intel on Thursday said that recently-issued pa...     Intel   INTEL CORP
# 3  Chipmaker Intel reports earnings on Thursday, ...     Intel   INTEL CORP
# 4  Intel stock rose more than 4.5 percent after t...     Intel   INTEL CORP
#
#   ticker
# 0   INTC
# 1   INTC
# 2   INTC
# 3   INTC
# 4   INTC

# %%
# master.to_csv('df_with_tickers.csv', index=False)

# %% [markdown]
# ### BERT

# %%
from transformers import BertTokenizer, BertForSequenceClassification, pipeline
import torch

# %%
tokenizer = BertTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = BertForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %%
def sentiment_score(text):
    texts = tokenizer.encode(text, return_tensors='pt')
    result = model(texts)
    return int(torch.argmax(result.logits))+1

# %%
master['sentiment'] = master['text'].apply(lambda x: sentiment_score(x[:512]))

# %%
master.head()
# Out:
#                                                title  published  \
# 0  Intel's alleged security flaw could cost chipm... 2018-01-03
# 1  Intel CEO: We believe we have the right fixes ... 2018-01-03
# 2  Intel just warned that its patches can cause p... 2018-01-12
# 3  Intel could breakout on earnings, here’s how t... 2018-01-24
# 4        Intel set to report earnings after the bell 2018-01-25
#
#                                                 text org_names matched_name  \
# 0  A report alleging Intel chips have a security ...     Intel   INTEL CORP
# 1  Intel CEO Brian Krzanich said researchers at G...     Intel   INTEL CORP
# 2  Intel on Thursday said that recently-issued pa...     Intel   INTEL CORP
# 3  Chipmaker Intel reports earnings on Thursday, ...     Intel   INTEL CORP
# 4  Intel stock rose more than 4.5 percent after t...     Intel   INTEL CORP
#
#   ticker  sentiment
# 0   INTC          1
# 1   INTC          1
# 2   INTC          2
# 3   INTC          1
# 4   INTC          1

# %%
master.shape
# Out:
# (2493, 7)

# %% [markdown]
# ### Article novelty

# %%
from datetime import timedelta
master['published'] = pd.to_datetime(master['published'])
# Out:
# C:\Users\slepo\AppData\Local\Temp\ipykernel_158592\2471448161.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master['published'] = pd.to_datetime(master['published'])

# %%
novelty = master.copy()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def compute_similarity(text1, text2):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform([text1, text2])
    cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
    return cosine_sim

# %%
def check_similarity(row1, row2):
    if row1['matched_name'] == row2['matched_name']:
        delta_days = abs((row1['published'] - row2['published']).days)
        if delta_days <= 14:
            similarity = compute_similarity(row1['text'], row2['text'])
            return similarity
    return None

# %%
import time
t1 = time.time()
print('Started...')

rows_to_delete = np.zeros(len(novelty), dtype=bool)

# iterate through df, compare the current row with subsequent rows only
for i, row1 in novelty.iterrows():
    for j, row2 in novelty.iloc[i+1:].iterrows():
        similarity = check_similarity(row1, row2)
        if similarity is not None and similarity < 0.7:
            rows_to_delete[i] = True
            break  
            
# remove marked rows 
novelty = novelty[~rows_to_delete]

t = time.time()-t1
print("COMPLETED IN:", t)
# Out:
# Started...
# COMPLETED IN: 69.44305109977722

# %%
master.shape
# Out:
# (2493, 7)

# %%
novelty.head()
# Out:
#                                                  title  published  \
# 10   Intel's alleged security flaw could cost chipm... 2018-01-03
# 90              Intel Promotes Four Corporate Officers 2018-01-31
# 91   Tesla delivers 1,550 Model 3 sedans and 29,870... 2018-01-03
# 92   Cramer Remix: Tesla’s stock is up for one simp... 2018-01-09
# 103  Tesla's Model 3 deliveries fall short of estim... 2018-01-04
#
#                                                   text org_names matched_name  \
# 10   Intel's alleged security flaw could cost chipm...     Intel   INTEL CORP
# 90   NEWS HIGHLIGHTS Intel promotes Leslie S. Culbe...     Intel   INTEL CORP
# 91   Tesla is apparently still deep in the circles ...     Tesla  Tesla, Inc.
# 92   Cramer Remix: Teslas stock is up for one simpl...     Tesla  Tesla, Inc.
# 103  Tesla's Model 3 deliveries fall short of estim...     Tesla  Tesla, Inc.
#
#     ticker  sentiment
# 10    INTC          1
# 90    INTC          4
# 91    TSLA          1
# 92    TSLA          2
# 103   TSLA          1

# %%
# novelty.to_csv('df_with_novelty.csv', index=False)

# %% [markdown]
# ### Retreiveing data from API

# %%
master02 = novelty.copy()

# %%
# open date - day after publication, close date - 3 days after publication
def get_open_price(ticker, published_date):
    open_date = published_date + timedelta(days=1)
    end_date = published_date + timedelta(days=2) # not included
    ticker_data = yf.download(ticker, start=open_date, end=end_date)
    if not ticker_data.empty:
        return ticker_data['Open'][0]
    else:
        return None

def get_close_price(ticker, published_date):
    
    for i in range(3):  # try up to 3 days after the published_date in case it's weekened 
        close_date = published_date + timedelta(days=i+3)
        end_date = published_date + timedelta(days=i+4)
        ticker_data = yf.download(ticker, start=close_date, end=end_date)
        if not ticker_data.empty:
            return ticker_data['Close'][0]
    return None

# %%
t1 = time.time()

master02['open_price'] = master02.apply(lambda row: get_open_price(row['ticker'], row['published']), axis=1)
master02['close_price'] = master02.apply(lambda row: get_close_price(row['ticker'], row['published']), axis=1)

t = time.time()-t1
print("COMPLETED IN:", t)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MBLY']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MBLY']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PSUS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NFLX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NFLX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NFLX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPOT']: Exception("%ticker%: Data doesn't exist for startDate = 1515560400, endDate = 1515646800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PLNT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516251600, endDate = 1516338000")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516165200, endDate = 1516251600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516165200, endDate = 1516251600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516165200, endDate = 1516251600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516856400, endDate = 1516942800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516942800, endDate = 1517029200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1514955600, endDate = 1515042000")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1514955600, endDate = 1515042000")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1515214800, endDate = 1515301200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516338000, endDate = 1516424400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516338000, endDate = 1516424400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516770000, endDate = 1516856400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516856400, endDate = 1516942800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1516942800, endDate = 1517029200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517288400, endDate = 1517374800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517374800, endDate = 1517461200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517461200, endDate = 1517547600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517461200, endDate = 1517547600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517461200, endDate = 1517547600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517461200, endDate = 1517547600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: Exception("%ticker%: Data doesn't exist for startDate = 1517461200, endDate = 1517547600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BGS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-07 00:00:00 -> 2018-01-08 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['D']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['D']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['T']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-21 00:00:00 -> 2018-01-22 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-21 00:00:00 -> 2018-01-22 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-21 00:00:00 -> 2018-01-22 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-28 00:00:00 -> 2018-01-29 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NYT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSFT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-15 00:00:00 -> 2018-01-16 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-28 00:00:00 -> 2018-01-29 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-28 00:00:00 -> 2018-01-29 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-28 00:00:00 -> 2018-01-29 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-21 00:00:00 -> 2018-01-22 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPGI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-06 00:00:00 -> 2018-01-07 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-15 00:00:00 -> 2018-01-16 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-15 00:00:00 -> 2018-01-16 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FCIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-15 00:00:00 -> 2018-01-16 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DBX']: Exception("%ticker%: Data doesn't exist for startDate = 1515819600, endDate = 1515906000")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVDA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AXP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AXP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MLI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KO']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-20 00:00:00 -> 2018-01-21 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HON']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HON']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-07 00:00:00 -> 2018-01-08 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HON']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HON']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HON']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KR']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KR']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KR']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KR']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-14 00:00:00 -> 2018-01-15 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PLTK']: Exception("%ticker%: Data doesn't exist for startDate = 1517288400, endDate = 1517374800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SBUX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-28 00:00:00 -> 2018-01-29 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHK']: Exception("%ticker%: Data doesn't exist for startDate = 1517374800, endDate = 1517461200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHK']: Exception("%ticker%: Data doesn't exist for startDate = 1517374800, endDate = 1517461200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: Exception("%ticker%: Data doesn't exist for startDate = 1514869200, endDate = 1514955600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: Exception("%ticker%: Data doesn't exist for startDate = 1515128400, endDate = 1515214800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: Exception("%ticker%: Data doesn't exist for startDate = 1514869200, endDate = 1514955600")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: Exception("%ticker%: Data doesn't exist for startDate = 1514869200, endDate = 1514955600")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASLN']: Exception("%ticker%: Data doesn't exist for startDate = 1515042000, endDate = 1515128400")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSCI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-13 00:00:00 -> 2018-01-14 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WFRD']: Exception("%ticker%: Data doesn't exist for startDate = 1514955600, endDate = 1515042000")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PFS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-01-27 00:00:00 -> 2018-01-28 00:00:00)')
# ...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KRNY']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KRNY']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LOPE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LOPE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FFIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FFIC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HCKT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HCKT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COST']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COST']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MT']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CODA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CODA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARCB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARCB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['IBN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['IBN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EMP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EMP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EMP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-05 00:00:00 -> 2018-02-06 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FFWM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FFWM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEIS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEIS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EXLS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EXLS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALEX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALEX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KOSS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KOSS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CACC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CACC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHKP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHKP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LEVI']: Exception("%ticker%: Data doesn't exist for startDate = 1517634000, endDate = 1517720400")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LEVI']: Exception("%ticker%: Data doesn't exist for startDate = 1517720400, endDate = 1517806800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LEVI']: Exception("%ticker%: Data doesn't exist for startDate = 1517806800, endDate = 1517893200")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FNF']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FNF']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['STC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['STC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HNI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HNI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FMNB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FMNB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NSSC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NSSC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DVA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FUSB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FUSB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SAH']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['SAH']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KTCC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KTCC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MRBK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MRBK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['VNDA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['VNDA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CZFS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-03 00:00:00 -> 2018-02-04 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CZFS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-02-04 00:00:00 -> 2018-02-05 00:00:00)')
# [*********************100%%**********************]  1 of 1 completed
# COMPLETED IN: 588.6957583427429

# %%
master02.head()
# Out:
#                                                  title  published  \
# 10   Intel's alleged security flaw could cost chipm... 2018-01-03
# 90              Intel Promotes Four Corporate Officers 2018-01-31
# 91   Tesla delivers 1,550 Model 3 sedans and 29,870... 2018-01-03
# 92   Cramer Remix: Tesla’s stock is up for one simp... 2018-01-09
# 103  Tesla's Model 3 deliveries fall short of estim... 2018-01-04
#
#                                                   text org_names matched_name  \
# 10   Intel's alleged security flaw could cost chipm...     Intel   INTEL CORP
# 90   NEWS HIGHLIGHTS Intel promotes Leslie S. Culbe...     Intel   INTEL CORP
# 91   Tesla is apparently still deep in the circles ...     Tesla  Tesla, Inc.
# 92   Cramer Remix: Teslas stock is up for one simpl...     Tesla  Tesla, Inc.
# 103  Tesla's Model 3 deliveries fall short of estim...     Tesla  Tesla, Inc.
#
#     ticker  sentiment  open_price  close_price
# 10    INTC          1   43.520000    44.740002
# 90    INTC          4   47.700001    44.520000
# 91    TSLA          1   20.858000    22.427334
# 92    TSLA          2   22.146667    22.414667
# 103   TSLA          1   21.108000    22.427334

# %%
#master02.to_csv('df_with_price.csv', index=False)

# %%
# t1 = time.time()
# t = time.time()-t1
# print("COMPLETED IN:", t)
